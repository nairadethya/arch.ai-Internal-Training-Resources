# %% [markdown]
# <h1 align="justify"> Numpy, Pandas and Matplotlib <h1>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
#  - Widely used python library for scietific computation
#  - Compared to python lists, numpy is way faster, as it needs less memory as it deals with only numbers. Numpy arrays have contiguous memory locations unlike lists whoch store data in random memory locations.

# %%
import numpy as np
a = [1,2,3] #list
A=np.array([1,2,3]) # a numpy array

# %%
b=[4,5,6]
B=np.array([4,5,6])

# %%
a*b #error

# %%
A*B #now thats numpy

# %%
x=np.array([[2,3],[4,5],[6,7],[8,9],[100,1000]])
print(x.shape,'\n')

#to transpose the array
x.transpose        
print(x,'\n')
print(x.shape,'\n')

# %%
#datatype
x.dtype

# %%
# total size
x.nbytes

# %%
# number of elements
x.size

# %%
# Get a specific element [r, c]
x[2, 0]

# %%
# Get a specific row 
print(x[0, :])
# Get a specific column
print(x[:, 1])
# Getting a little more fancy [startindex:endindex:stepsize]
print(x[0:-1:2,1])

# %%
# All ones matrix,  literally any degree matrix!
np.ones((4,2,2), dtype='int32')

# %%
# Any other number
np.full((2,2,2), 1299)

# %%
# Random decimal numbers
np.random.rand(4,2)

# %%
# The identity matrix
np.identity(5)

# %%
# Lets get a range of values
a= np.arange(1,101)
print(a)

# now lets change their shape. This can be very useful in many places.
a.reshape(4,5,5)

# %% [markdown]
#   ***
#   <hr/>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Pandas is another powerful python library that allows high performance data processing ranging from data loading to manipulating/analyzing to remodelling. Being familiar with this library is crucial to any machine learning engineer/ data scientist
#
# Pandas is just a short form of 'Panel Data'.
# You can either handle data in one dimension known as a 'pandas series',
# or a two dimensional form known as 'pandas dataframe'. Both of these are built on numpy
#
# Lets dive in

# %%
#first and foremost
import pandas as pd

# %% [markdown]
# first lets load data
# You usually load data using
#
# ### df = pd.read_csv(' <your csv file with path to directory> ').   You must certainly try this out
#
# But now lets load data from an online dataset. Instead of the path to you csv file, just pass the url.

# %%
df=pd.read_csv('https://srea64.github.io/msan622/project/pokemon.csv')

df.head()

# %% [markdown]
# So, this is a dataset of different pokemons  with their properties. Lets play with it using pandas

# %%
df.describe()

# %% [markdown]
# Now we know there are 778 rows, mean value of each column, standard deviation from mean, minimum value, where the 25th, 50th and 75th percentile values lie, and the maximum value

# %%
df.isna().sum() #to check for null values

# %% [markdown]
# Many datasets may contain incomplete data. It may contain NaN (Not A Number ) values which we have to handle separately. Here, we have no such values.

# %%
df.dtypes  #know datatypes

# %%
# df.info does the same job better
df.info()

# %%
##displaying unique Type of pokemon

df['Type'].unique()

# %%
df['Type'].nunique()   #counting how many unique values

# %%
#List those pokemon whos defense > 100
df[df['Defense']>100]

# %%
#choose specific rrows and cols
df.loc[2:10,['Attack','Defense']]

# %% [markdown]
# Now lets rename columns to our convenience

# %%
print(df.columns)
df.rename(columns = {'Health Points':'hp','Attack':'atk','Defense':'def','Special Attack':'spl atk','Special Defense':'spl def','Generation':'gen'})

print(df.columns)

# %% [markdown]
# Here no change took place as one the df.rename was executed, after that the changes were rreversed. To avoid that and make changes permanent, we use the parameter **inplace=True**

# %%
df.rename(columns = {'Health Points':'hp','Attack':'atk','Defense':'def','Special Attack':'spl atk','Special Defense':'spl def','Generation':'gen'},inplace=True)

print(df.columns)

# %% [markdown]
# # Groupby method

# %%
df_by_generation=df.groupby('gen').mean()
df_by_generation
#Here we grouped by generation

# %%
# mean id doesnt make sense
df_by_generation.drop('id',axis=1,inplace=True)  #axis=0 means rows and axis=1 means cols   (by default, axis=0)
df_by_generation

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Matplotlib is a cross-platform, data visualization and graphical plotting library for Python and  NumPy.
# Developers can also use matplotlib’s APIs (Application Programming Interfaces) to embed plots in GUI applications.
#
# In fact, matplotlib was originally written as an open source alternative for MATLAB.

# %% [markdown]
# Understanding matplotlib’s pyplot API is key to understanding how to work with plots:
#
# 1. matplotlib.pyplot.figure:---Figure is the top-level container. It includes everything visualized in a plot including one or more Axes.
#
# 2. matplotlib.pyplot.axes:---Axes contain most of the elements in a plot: Axis, Tick, Line2D, Text, etc., and sets the coordinates. It is the area in which data is plotted. Axes include the X-Axis, Y-Axis, and possibly a Z-Axis, as well.
#
# %matplotlib inline will lead to static images of your plot embedded in the notebook

# %% [markdown]
# ###How to Create Matplotlib Plots

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# Plot some numbers:
plt.plot([1, 2, 3]) 
plt.title("LinePlot") 

# Display the plot:
plt.show()

# %%
# Data labels, sizes, and colors are defined:
labels = 'Broccoli', 'Chocolate Cake', 'Blueberries', 'Raspberries'
sizes = [30, 330, 245, 210]
colors = ['green', 'brown', 'blue', 'red']

# Data is plotted:
plt.pie(sizes, labels=labels, colors=colors)

plt.axis('equal')
plt.title("Pie Plot")
plt.show()

# %% [markdown]
# ###Plotting a Numpy Array

# %%
# Create an ndarray on x axis using the numpy range() function:
x = np.arange(3,21)

# Store equation values on y axis:
y = 2 * x + 8 
plt.title("NumPy Array Plot")

# Plot values using x,y coordinates:
plt.plot(x,y)
plt.show()

# %% [markdown]
# ##Now lets try to visualize a pandas dataframe using matplotlib

# %%
gas=pd.read_csv('https://raw.githubusercontent.com/KeithGalli/matplotlib_tutorial/master/gas_prices.csv', error_bad_lines=False)
gas.head()

# %%
#First we create a canvas to plot
plt.figure(figsize=(8,5))

#Give a title to the canvas
plt.title('Gas Prices over Time (in USD)', fontdict={'fontweight':'bold', 'fontsize': 18})

#Now plot values from the pandas dataframe 
plt.plot(gas.Year, gas.USA, 'b.-', label='United States')
plt.plot(gas.Year, gas.Canada, 'r.-', label='Canada')
plt.plot(gas.Year, gas['South Korea'], 'g.-', label='South Korea')
plt.plot(gas.Year, gas.Australia, 'y.-', label='Australia')

# Another Way to plot many values!
# countries_to_look_at = ['Australia', 'USA', 'Canada', 'South Korea']
# for country in gas:
#     if country in countries_to_look_at:
#         plt.plot(gas.Year, gas[country], marker='.')

#How do you want the values in the x-axis to be spaced like
plt.xticks(gas.Year[::3].tolist()+[2011])

#give labels to axes
plt.xlabel('Year')
plt.ylabel('US Dollars')

#to show the legend. It automatically appears in a blank corner
plt.legend()

plt.savefig('Gas_price_figure.png', dpi=300)

plt.show()

# %% [markdown]
# Now you have a better picture of how oil prices grew over time in these countruies

# %% [markdown]
# ##You can also check out [this colab notebook](https://colab.research.google.com/github/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/04.00-Introduction-To-Matplotlib.ipynb#scrollTo=2UscaMo0ueLe) to check out more matplotlib work

# %% [markdown]
# #Task : Install and checkout Jupyter notebook and run the cells
